# %%
import pandas as pd

# %%
matches = pd.read_csv("matches.csv")

# %%
matches.head()
# Out:
#          Date           Time              Comp                Round  Day  \
# 0  06/08/2023          16:00  Community Shield  FA Community Shield  Sun
# 1  11/08/2023          20:00    Premier League          Matchweek 1  Fri
# 2  16/08/2023  22:00 (20:00)         Super Cup       UEFA Super Cup  Wed
# 3  19/08/2023          20:00    Premier League          Matchweek 2  Sat
# 4  27/08/2023          14:00    Premier League          Matchweek 3  Sun
#
#      Venue Result     GF     GA       Opponent  ...   PK  PKatt  xG.1 npxG  \
# 0  Neutral      D  1 (1)  1 (4)        Arsenal  ...  0.0    0.0   NaN  NaN
# 1     Away      W      3      0        Burnley  ...  0.0    0.0   1.9  1.9
# 2     Home      D  1 (5)  1 (4)     es Sevilla  ...  0.0    0.0   NaN  NaN
# 3     Home      W      1      0  Newcastle Utd  ...  0.0    0.0   1.0  1.0
# 4     Away      W      2      1  Sheffield Utd  ...  0.0    1.0   3.5  2.8
#
#   npxG/Sh G-xG np:G-xG Match Report.1             Team ï»¿Date
# 0     NaN  NaN     NaN   Match Report  Manchester_City     NaN
# 1    0.12  1.1     1.1   Match Report  Manchester_City     NaN
# 2     NaN  NaN     NaN   Match Report  Manchester_City     NaN
# 3    0.07  0.0     0.0   Match Report  Manchester_City     NaN
# 4    0.10 -1.5    -0.8   Match Report  Manchester_City     NaN
#
# [5 rows x 48 columns]

# %%
matches_columns = matches.columns
print(matches_columns)
# Out:
# Index(['Date', 'Time', 'Comp', 'Round', 'Day', 'Venue', 'Result', 'GF', 'GA',
#        'Opponent', 'xG', 'xGA', 'Poss', 'Attendance', 'Captain', 'Formation',
#        'Opp Formation', 'Referee', 'Match Report', 'Notes', 'Date.1', 'Time.1',
#        'Comp.1', 'Round.1', 'Day.1', 'Venue.1', 'Result.1', 'GF.1', 'GA.1',
#        'Opponent.1', 'Gls', 'Sh', 'SoT', 'SoT%', 'G/Sh', 'G/SoT', 'Dist', 'FK',
#        'PK', 'PKatt', 'xG.1', 'npxG', 'npxG/Sh', 'G-xG', 'np:G-xG',
#        'Match Report.1', 'Team', 'ï»¿Date'],
#       dtype='object')

# %%
columns_to_keep = [
    'Date', 'Time', 'Comp', 'Round', 'Venue', 'Result', 'GF', 'GA', 
    'Opponent', 'Formation', 'Referee', 'Sh', 'SoT', 'Dist', 'FK', 
    'PK', 'PKatt', 'Team'
]

columns_to_drop = [
    'Day', 'xG', 'xGA', 'Poss', 'Attendance', 'Captain', 'Opp Formation',
    'Match Report', 'Notes', 'Date.1', 'Time.1', 'Comp.1', 'Round.1', 
    'Day.1', 'Venue.1', 'Result.1', 'GF.1', 'GA.1', 'Opponent.1', 
    'Gls', 'SoT%', 'G/Sh', 'G/SoT', 'xG.1', 'npxG', 'npxG/Sh', 
    'G-xG', 'np:G-xG', 'Match Report.1', 'ï»¿Date'
]

# %%
matches = matches[columns_to_keep]

matches_columns = matches.columns
print(matches_columns)
# Out:
# Index(['Date', 'Time', 'Comp', 'Round', 'Venue', 'Result', 'GF', 'GA',
#        'Opponent', 'Formation', 'Referee', 'Sh', 'SoT', 'Dist', 'FK', 'PK',
#        'PKatt', 'Team'],
#       dtype='object')

# %%
matches.head()
# Out:
#          Date           Time              Comp                Round    Venue  \
# 0  06/08/2023          16:00  Community Shield  FA Community Shield  Neutral
# 1  11/08/2023          20:00    Premier League          Matchweek 1     Away
# 2  16/08/2023  22:00 (20:00)         Super Cup       UEFA Super Cup     Home
# 3  19/08/2023          20:00    Premier League          Matchweek 2     Home
# 4  27/08/2023          14:00    Premier League          Matchweek 3     Away
#
#   Result     GF     GA       Opponent Formation            Referee    Sh  SoT  \
# 0      D  1 (1)  1 (4)        Arsenal   4-2-3-1     Stuart Attwell   8.0  4.0
# 1      W      3      0        Burnley   4-2-3-1       Craig Pawson  17.0  8.0
# 2      D  1 (5)  1 (4)     es Sevilla   4-2-3-1  François Letexier  23.0  7.0
# 3      W      1      0  Newcastle Utd   4-2-3-1       Robert Jones  14.0  4.0
# 4      W      2      1  Sheffield Utd   4-2-3-1     Jarred Gillett  29.0  9.0
#
#    Dist   FK   PK  PKatt             Team
# 0   NaN  NaN  0.0    0.0  Manchester_City
# 1  13.9  0.0  0.0    0.0  Manchester_City
# 2   NaN  NaN  0.0    0.0  Manchester_City
# 3  17.9  0.0  0.0    0.0  Manchester_City
# 4  17.3  2.0  0.0    1.0  Manchester_City

# %%
matches = matches[matches['Comp'] == 'Premier League']
matches.head()
# Out:
#          Date   Time            Comp        Round Venue Result GF GA  \
# 1  11/08/2023  20:00  Premier League  Matchweek 1  Away      W  3  0
# 3  19/08/2023  20:00  Premier League  Matchweek 2  Home      W  1  0
# 4  27/08/2023  14:00  Premier League  Matchweek 3  Away      W  2  1
# 5  02/09/2023  15:00  Premier League  Matchweek 4  Home      W  5  1
# 6  16/09/2023  15:00  Premier League  Matchweek 5  Away      W  3  1
#
#         Opponent Formation         Referee    Sh   SoT  Dist   FK   PK  PKatt  \
# 1        Burnley   4-2-3-1    Craig Pawson  17.0   8.0  13.9  0.0  0.0    0.0
# 3  Newcastle Utd   4-2-3-1    Robert Jones  14.0   4.0  17.9  0.0  0.0    0.0
# 4  Sheffield Utd   4-2-3-1  Jarred Gillett  29.0   9.0  17.3  2.0  0.0    1.0
# 5         Fulham   4-2-3-1  Michael Oliver   6.0   4.0  14.8  0.0  1.0    1.0
# 6       West Ham   4-2-3-1     Andy Madley  29.0  13.0  16.4  1.0  0.0    0.0
#
#               Team
# 1  Manchester_City
# 3  Manchester_City
# 4  Manchester_City
# 5  Manchester_City
# 6  Manchester_City

# %%
matches['Team'].value_counts()
# Out:
# Team
# Manchester_City            116
# Liverpool                  116
# Aston_Villa                115
# Manchester_United          114
# Arsenal                    112
# Chelsea                    110
# Tottenham_Hotspur          103
# Brighton_&_Hove_Albion      97
# West_Ham_United             96
# Crystal_Palace              92
# Fulham                      92
# Wolverhampton_Wanderers     90
# Nottingham_Forest           90
# Everton                     89
# Bournemouth                 89
# Brentford                   87
# Newcastle                   52
# Newcastle_United            49
# Southampton                 45
# Luton_Town                  45
# Leicester_City              44
# Burnley                     43
# Ipswich_Town                43
# Sheffield_United            42
# Name: count, dtype: int64
